# %%
import sys
sys.path.append("..")

from src.model_utils import analyze_lyrics
from src.nlp import extract_emotions

# %%
text = "I feel broken and alone"

result = analyze_lyrics(text)

print(result)
# Out:
# {'emotions': {'sadness': 0.9906054139137268, 'neutral': 0.0030479927081614733, 'anger': 0.002141956239938736, 'disgust': 0.0017406767001375556, 'surprise': 0.0010396211873739958, 'joy': 0.0008016067440621555, 'fear': 0.0006227280828170478}, 'valence': np.float64(0.44), 'energy': np.float64(0.5), 'mode': 'minor', 'mood': 'Chill 🎧', 'key_suggestions': [{'key': 'E', 'confidence': np.float64(0.32)}, {'key': 'B', 'confidence': np.float64(0.19)}, {'key': 'A#', 'confidence': np.float64(0.12)}]}

# %%
text = """
I feel alone tonight,
everything is falling apart,
nothing makes sense anymore
"""

result = analyze_lyrics(text)

print(result)
# Out:
# {'emotions': {'sadness': 0.976191520690918, 'fear': 0.00786770973354578, 'neutral': 0.007343984674662352, 'disgust': 0.0038290414959192276, 'surprise': 0.00281227333471179, 'anger': 0.0012716513592749834, 'joy': 0.0006838475237600505}, 'valence': np.float64(0.34), 'energy': np.float64(0.5), 'mode': 'major', 'mood': 'Chill 🎧', 'key_suggestions': [{'key': 'E', 'confidence': np.float64(0.28)}, {'key': 'F', 'confidence': np.float64(0.18)}, {'key': 'B', 'confidence': np.float64(0.16)}]}

# %%
text = "We are alive, dancing all night, everything feels amazing and bright"
print(analyze_lyrics(text))
# Out:
# {'emotions': {'surprise': 0.6474302411079407, 'joy': 0.3053262233734131, 'neutral': 0.028068602085113525, 'fear': 0.007672840263694525, 'anger': 0.005138913635164499, 'sadness': 0.004743010737001896, 'disgust': 0.0016201817197725177}, 'valence': np.float64(0.36), 'energy': np.float64(0.54), 'mode': 'major', 'mood': 'Chill 🎧', 'key_suggestions': [{'key': 'A', 'confidence': np.float64(0.3)}, {'key': 'C', 'confidence': np.float64(0.12)}, {'key': 'F', 'confidence': np.float64(0.09)}]}

# %%
text = "I hate you, I’m furious, everything is chaos and rage"
print(analyze_lyrics(text))
# Out:
# {'emotions': {'anger': 0.9888299107551575, 'fear': 0.003582443343475461, 'neutral': 0.002180928597226739, 'surprise': 0.0016269817715510726, 'disgust': 0.001560491626150906, 'sadness': 0.001530962996184826, 'joy': 0.000688339292537421}, 'valence': np.float64(0.4), 'energy': np.float64(0.59), 'mode': 'minor', 'mood': 'Chill 🎧', 'key_suggestions': [{'key': 'C', 'confidence': np.float64(0.35)}, {'key': 'E', 'confidence': np.float64(0.15)}, {'key': 'B', 'confidence': np.float64(0.12)}]}

# %%
text = "Sometimes I feel happy, sometimes I feel lost, I don’t know anymore"
print(analyze_lyrics(text))
# Out:
# {'emotions': {'sadness': 0.9852783679962158, 'joy': 0.005473146680742502, 'neutral': 0.004737100098282099, 'disgust': 0.0016130255535244942, 'surprise': 0.0013937191106379032, 'fear': 0.0009402438881807029, 'anger': 0.000564323621802032}, 'valence': np.float64(0.35), 'energy': np.float64(0.42), 'mode': 'minor', 'mood': 'Chill 🎧', 'key_suggestions': [{'key': 'F', 'confidence': np.float64(0.26)}, {'key': 'E', 'confidence': np.float64(0.22)}, {'key': 'A#', 'confidence': np.float64(0.16)}]}
